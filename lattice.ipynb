# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
a = 1
a1 = (a, 0)
a2 = (a/2, a*np.sqrt(3)/2)
Rs = [(0,0), (a/2, a/(2*np.sqrt(3)))]
for R in Rs:
    for i in range(5):
        for j in range(5):
            plt.plot(R[0]+i*a1[0]+j*a2[0], R[1]+i*a1[1]+j*a2[1], 'k.')
